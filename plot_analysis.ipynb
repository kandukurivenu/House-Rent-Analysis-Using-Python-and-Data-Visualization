# %% [markdown]
# <a href="https://colab.research.google.com/github/kandukurivenu/House-Rent-Analysis-Using-Python-and-Data-Visualization/blob/main/plot_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Import Library**

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/House_Rent_Dataset.csv')

# %%
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %% [markdown]
# ## **Check Null Values**

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %% [markdown]
# ## **Check Duplicate Values**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **Check Column Name**

# %%
df.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %% [markdown]
# ## **Get Average,Median,Highest,Lowest Rent**

# %%
print("The Average Rent is",round(df['Rent'].mean()))
print("The Median Rent is",round(df['Rent'].median()))
print("The Highest Rent is",round(df['Rent'].max()))
print("The Minimum Rent is",round(df['Rent'].min()))
# Out:
# The Average Rent is 34993
# The Median Rent is 16000
# The Highest Rent is 3500000
# The Minimum Rent is 1200

# %% [markdown]
# ## **Top 10 highest rent and cities**

# %%
print("\033[1m                Top 10 Highest Rent:\033[0m")
print(df[['City','Area Locality','BHK','Rent']].sort_values(by='Rent',ascending=False).head(10))
# Out:
#                 Top 10 Highest Rent:
#            City             Area Locality  BHK     Rent
# 1837  Bangalore              Marathahalli    3  3500000
# 1001     Mumbai                      Juhu    4  1200000
# 827      Mumbai     Raheja Artesia, Worli    4  1000000
# 1329     Mumbai              Breach Candy    4   850000
# 1459     Mumbai   Lady Ratan Tower, Worli    4   700000
# 1484     Mumbai                 Khar West    4   680000
# 1319     Mumbai                 Khar West    5   650000
# 1384     Mumbai               Bandra West    5   600000
# 726      Mumbai  Mount Marry, Bandra West    4   600000
# 3656    Chennai              Vettuvankeni    2   600000

# %% [markdown]
# ## **Top 10 Minimum Rent and cities**

# %%
print("\033[1m                Top 10 Minimum Rent:\033[0m")
print(df[['City','Area Locality','BHK','Rent']].sort_values(by='Rent',ascending=True).head(10))
# Out:
#                 Top 10 Minimum Rent:
#            City       Area Locality  BHK  Rent
# 4076  Hyderabad       Uppal, NH 2 2    3  1200
# 285     Kolkata          Santoshpur    1  1500
# 471     Kolkata         Shyam Bazar    1  1800
# 2475      Delhi           Ram Nagar    2  2000
# 146     Kolkata      Behala silpara    2  2200
# 506     Kolkata           Baranagar    1  2200
# 4220  Hyderabad  Rhoda Mistri Nagar    1  3000
# 3068    Chennai              Ennore    1  3000
# 306     Kolkata             Hatiara    1  3000
# 3378    Chennai             Mangadu    1  3000

# %% [markdown]
# ## **Scatter Plot on House Rents vs House Sizes and City**

# %%
plt.figure(figsize=(14, 6))
plt.ticklabel_format(style='plain')
sns.scatterplot(data=df, x='Size', y='Rent', hue='City', s=120, marker='s')
plt.title('Size vs Rent vs City', fontweight='bold')
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Bar Plot for Cities house count**

# %%
No_of_house=df['City'].value_counts()
colors = ['pink', 'blue', 'green', 'orange', 'Black','Red']
func=No_of_house.plot(kind='bar',color=colors)
for p in func.patches:
    func.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.xlabel('City',fontweight='bold')
plt.ylabel('Number of Houses',fontweight='bold')
plt.show()

# %% [markdown]
# ## **Tenant Preference According to Furnishing Status**

# %%
grouped=df.groupby('Tenant Preferred')
population_sum = grouped['Furnishing Status'].value_counts()
print(population_sum)
# Out:
# Tenant Preferred  Furnishing Status
# Bachelors         Unfurnished           409
#                   Semi-Furnished        324
#                   Furnished              97
# Bachelors/Family  Semi-Furnished       1675
#                   Unfurnished          1261
#                   Furnished             508
# Family            Semi-Furnished        252
#                   Unfurnished           145
#                   Furnished              75
# Name: count, dtype: int64

# %% [markdown]
# ## **Bar Plot on Different Types of Tenant Preferred**

# %%
preffered=df['Tenant Preferred'].value_counts()
mac=preffered.plot(kind='bar',color='pink')
for p in mac.patches:
    mac.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.show()

# %% [markdown]
# ## **Barplot Tenant Preference VS Rent**

# %%
ab = sns.barplot(data=df,x='Tenant Preferred', y='Rent',ci=None)
for p in ab.patches:
    ab.annotate(int(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.show()
# Out:
# /tmp/ipython-input-2483319077.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ab = sns.barplot(data=df,x='Tenant Preferred', y='Rent',ci=None)

# %% [markdown]
# ## **Percentage of furnishing status**

# %%
per_un=df['Furnishing Status'].value_counts()
per_un
# Out:
# Furnishing Status
# Semi-Furnished    2251
# Unfurnished       1815
# Furnished          680
# Name: count, dtype: int64

# %%
percentage_furnished = round((per_un['Furnished'] / per_un.sum()) * 100)
percentage_semi_furnished = round((per_un['Semi-Furnished'] / per_un.sum()) * 100)
percentage_unfurnished = round((per_un['Unfurnished'] / per_un.sum()) * 100)

X = [percentage_furnished, percentage_semi_furnished, percentage_unfurnished]
labels = ['Furnished','Semi-Furnished','Unfurnised']
print("Percentage of Furnished:", percentage_furnished, '%')
print("Percentage of Semi-Furnished:", percentage_semi_furnished, '%')
print("Percentage of Unfurnished:", percentage_unfurnished, '%')
# Out:
# Percentage of Furnished: 14 %
# Percentage of Semi-Furnished: 47 %
# Percentage of Unfurnished: 38 %

# %% [markdown]
# ## **Pie chart for furnishing status**

# %%
plt.pie(X,labels=labels,autopct='%.2f%%')
plt.title('Furnishing Status')

plt.show()

# %% [markdown]
# ## **Bar Plot for City vs House Rent**

# %%
sns.barplot(data=df, x='City', y='Rent')
plt.show()

# %% [markdown]
# ## **BarPlot Furnishing Status**

# %%
found=df['Furnishing Status'].value_counts().plot(kind='bar',color='grey')
plt.grid(True)
for p in found.patches:
    found.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.show()

# %% [markdown]
# ## **Distribution of different number of BHK available in the Dataset**

# %%
plt.figure(figsize=(14,6))
Bhk=df['BHK'].value_counts().plot(kind='bar',color='purple')
for p in Bhk.patches:
    Bhk.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points')
plt.show()

# %% [markdown]
# ## **Heatmap on BHK vs Area Type**

# %%
colormap=plt.cm.plasma
sns.heatmap(pd.crosstab(df["Area Type"],
                        df["BHK"]),
                        cmap = colormap);

# %% [markdown]
# ## **Barplot city ,rent and area type**

# %%
plt.figure(figsize=(20,6))
me=sns.barplot(data=df,x='City',y='Rent',hue='Area Type', ci=None)
for p in me.patches:
    height = p.get_height()
    if not np.isnan(height):
        plt.text(p.get_x() + p.get_width() / 2., height, int(height), ha='center', va='bottom', color='black')

plt.show()
# Out:
# /tmp/ipython-input-778575964.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   me=sns.barplot(data=df,x='City',y='Rent',hue='Area Type', ci=None)

# %% [markdown]
# ## **Distribution of Rent**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Rent'], kde=True)
plt.title("Distribution of Rent Prices")
plt.xlabel("Rent")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## **Rent vs Number of BHKs**

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='BHK', y='Rent')
plt.title("Rent Distribution by BHK")
plt.show()

# %% [markdown]
# ## **Furnishing Status vs Rent**

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x='Furnishing Status', y='Rent', ci=None)
plt.title("Average Rent by Furnishing Status")
plt.show()
# Out:
# /tmp/ipython-input-735745626.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Furnishing Status', y='Rent', ci=None)

# %% [markdown]
# ## **City vs Rent (Top 10 Cities)**

# %%
top_cities = df['City'].value_counts().head(10).index

plt.figure(figsize=(10,5))
sns.barplot(data=df[df['City'].isin(top_cities)], x='City', y='Rent', ci=None)
plt.xticks(rotation=45)
plt.title("Average Rent in Top 10 Cities")
plt.show()
# Out:
# /tmp/ipython-input-75068247.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df[df['City'].isin(top_cities)], x='City', y='Rent', ci=None)
